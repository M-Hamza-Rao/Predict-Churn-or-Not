# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Hamza-Rao/Predict-Churn-or-Not/blob/main/DeepLEarning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Churn or Not

# %%
import pandas as pd
from sklearn.model_selection import train_test_split as tts

# %%
df = pd.read_csv("Churn.csv")
df.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
X = pd.get_dummies(df.drop(['Churn','Customer ID'],axis=1))
Y = df['Churn'].apply(lambda x:1 if x=="Yes" else 0)

# %%
x_train, x_test, y_train, y_test = tts(X,Y,test_size=0.25)

# %%
x_train.head()
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 2839               0      41            20.00              1            0
# 4660               0      65           104.30              1            0
# 730                0      65            74.20              0            1
# 4102               0       6            59.15              0            1
# 5594               0      31            75.50              0            1
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 2839           1            0              1               0
# 4660           0            1              0               1
# 730            1            0              1               0
# 4102           1            0              1               0
# 5594           0            1              1               0
#
#       Phone Service_No  ...  Total Charges_995.35  Total Charges_996.45  \
# 2839                 0  ...                     0                     0
# ...

# %%
y_train.head()
# Out:
# 2839    0
# 4660    0
# 730     0
# 4102    0
# 5594    0
# Name: Churn, dtype: int64

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(units=32,activation='relu',input_dim=len(x_train.columns)))
model.add(Dense(units=64,activation='relu'))
model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy",optimizer='sgd',metrics='accuracy')

# %%
model.fit(x_train,y_train,epochs=800,batch_size=32)
# Out:
# Epoch 1/800
# 166/166 [==============================] - 2s 7ms/step - loss: 0.5017 - accuracy: 0.7587
# Epoch 2/800
# 166/166 [==============================] - 1s 7ms/step - loss: 0.4809 - accuracy: 0.7736
# Epoch 3/800
# 166/166 [==============================] - 1s 6ms/step - loss: 0.4747 - accuracy: 0.7793
# Epoch 4/800
# 166/166 [==============================] - 1s 4ms/step - loss: 0.4712 - accuracy: 0.7823
# Epoch 5/800
# 166/166 [==============================] - 1s 4ms/step - loss: 0.4684 - accuracy: 0.7836
# Epoch 6/800
# 166/166 [==============================] - 1s 4ms/step - loss: 0.4666 - accuracy: 0.7842
# Epoch 7/800
# 166/166 [==============================] - 1s 4ms/step - loss: 0.4643 - accuracy: 0.7823
# Epoch 8/800
# 166/166 [==============================] - 1s 4ms/step - loss: 0.4628 - accuracy: 0.7829
# Epoch 9/800
# 166/166 [==============================] - 1s 4ms/step - loss: 0.4586 - accuracy: 0.7863
# Epoch 10/800
# ...

# %%
y_hat = model.predict(x_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 56/56 [==============================] - 0s 3ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.7825099375354913

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/tfModel_isChurn')
